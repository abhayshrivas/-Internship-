# %%
## 1.Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("weatherAUS.csv")

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
data.shape
# Out:
# (8425, 23)

# %%
# Droping Duplicates

# %%
data.drop_duplicates()
data.shape
# Out:
# (8425, 23)

# %%
# No duplicates values are present.

# %%
# Checking unique values

# %%
data.nunique()
# Out:
# Date             3004
# Location           12
# MinTemp           285
# MaxTemp           331
# Rainfall          250
# Evaporation       116
# Sunshine          140
# WindGustDir        16
# WindGustSpeed      52
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       34
# WindSpeed3pm       35
# Humidity9am        90
# Humidity3pm        94
# Pressure9am       384
# Pressure3pm       374
# Cloud9am            9
# Cloud3pm            9
# Temp9am           304
# Temp3pm           328
# RainToday           2
# RainTomorrow        2
# dtype: int64

# %%
# EDA

# %%
# Checking Null Values

# %%
data.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
# Except Date and location all features are having null values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
#  Filling Null Values
# For Continuous data

# %%
data["MinTemp"]=data["MinTemp"].replace('N',np.nan)

# %%
data['MinTemp']= data['MinTemp'].fillna(data['MinTemp'].mean())

# %%
data['MaxTemp']= data['MaxTemp'].fillna(data['MaxTemp'].mean())

data['Rainfall']= data['Rainfall'].fillna(data['Rainfall'].mean())

data['Evaporation']= data['Evaporation'].fillna(data['Evaporation'].mean())

data['Sunshine']= data['Sunshine'].fillna(data['Sunshine'].mean())

data['WindGustSpeed']= data['WindGustSpeed'].fillna(data['WindGustSpeed'].mean())

data['WindSpeed9am']= data['WindSpeed9am'].fillna(data['WindSpeed9am'].mean())

data['WindSpeed3pm']= data['WindSpeed3pm'].fillna(data['WindSpeed3pm'].mean())

data['Humidity9am']= data['Humidity9am'].fillna(data['Humidity9am'].mean())

data['Humidity3pm']= data['Humidity3pm'].fillna(data['Humidity3pm'].mean())

data['Pressure9am']= data['Pressure9am'].fillna(data['Pressure9am'].mean())

data['Pressure3pm']= data['Pressure3pm'].fillna(data['Pressure3pm'].mean())

data['Cloud9am']= data['Cloud9am'].fillna(data['Cloud9am'].mean())

data['Cloud3pm']= data['Cloud3pm'].fillna(data['Cloud3pm'].mean())

data['Temp9am']= data['Temp9am'].fillna(data['Temp9am'].mean())

data['Temp3pm']= data['Temp3pm'].fillna(data['Temp3pm'].mean())

# %%
# For Categorical Data

# %%
null_columns =['WindGustDir','WindDir9am','WindDir3pm']
for i in null_columns:
    data.fillna(data[i].mode()[0], inplace=True)

# %%
data['RainTomorrow'].value_counts()
# Out:
# No     6195
# Yes    1991
# N       239
# Name: RainTomorrow, dtype: int64

# %%
data["RainToday"]=data["RainToday"].replace('N',np.nan)

# %%
data["RainTomorrow"]=data["RainTomorrow"].replace('N',np.nan)

# %%
data['RainToday']= data['RainToday'].fillna(data['RainToday'].mode()[0])

# %%
data['RainTomorrow']= data['RainTomorrow'].fillna(data['RainTomorrow'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['year'] = data['Date'].dt.year
data['month'] = data['Date'].dt.month
data['day'] = data['Date'].dt.day

# %%
# Drop Date column:
data.drop('Date', axis = 1, inplace = True)
data.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6     5.389395  7.632205           W
# 1   Albury      7.4     25.1       0.0     5.389395  7.632205         WNW
# 2   Albury     12.9     25.7       0.0     5.389395  7.632205         WSW
# 3   Albury      9.2     28.0       0.0     5.389395  7.632205          NE
# 4   Albury     17.5     32.3       1.0     5.389395  7.632205           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  Cloud3pm  \
# 0           44.0          W        WNW  ...       1007.1  8.000000  4.503183
# 1           44.0        NNW        WSW  ...       1007.8  4.566622  4.503183
# 2           46.0          W        WSW  ...       1008.7  4.566622  2.000000
# 3           24.0         SE          E  ...       1012.8  4.566622  4.503183
# 4           41.0        ENE         NW  ...       1006.0  7.000000  8.000000
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 0     16.9     21.8         No            No  2008     12    1
# 1     17.2     24.3         No            No  2008     12    2
# 2     21.0     23.2         No            No  2008     12    3
# 3     18.1     26.5         No            No  2008     12    4
# 4     17.8     29.7         No            No  2008     12    5
#
# [5 rows x 25 columns]

# %%
#  Univariate Analysis

# %%
sns.countplot(y='Location',data=data)
plt.show()

# %%
# Melbourne has maximum common weather station where maximum area has been coverd followed by Williamtown.
# Uluru has lowest weather station where minimum area has been coverd followed by Adelaide.

# %%
# Distribution plot for the column MinTemp
sns.distplot(data["MinTemp"],color="b",kde_kws={"shade": True},)
plt.show()

# %%
# We can see, the data is normaly distributed.
# Maximum MinTemp lies in the range of 5 to 20. Before and after that Min temprature falls down.

# %%
# Distribution plot for the column MaxTemp
sns.distplot(data["MaxTemp"],color="b",kde_kws={"shade": True},)
plt.show()

# %%
# We can see, Max temprature has right skewed.
# But maximum MaxTemp lies in the range of 13 to 30. In which the Max temprature has maximum where from 30 Max temp falls down.

# %%
# Distribution plot for the column Rainfall
sns.distplot(data["Rainfall"],color="b",kde_kws={"shade": True},)
plt.show()

# %%
# Rainfall is not normaly distributed. Its a right skewed.
# Maximum rainsfalls in 0 to 50. After that is seem to have outliers.

# %%
# Distribution plot for the column Evaporation
sns.distplot(data["Evaporation"],color="b",kde_kws={"shade": True},)
plt.show()

# %%
# Evaporation is not normaly distributed. Its a right skewed.
# Maximum Evaporation in 0 to 20. After that is seem to have outliers.

# %%
sns.countplot(x='WindGustDir',data=data)
plt.show()

# %%
# The 'N' type of WindGust has a strongest wind in midnight.
# The 'NNW' direction of WingGust has lowest wind in mindnight.

# %%
sns.countplot(x='WindDir9am',data=data)
plt.show()

# %%
# "North' has maximum wind direction at 9am followed by SouthWest.
# 'SouthEast' has mimimum wind direction at 9am followed NNW.

# %%
sns.countplot(y='WindDir3pm',data=data)
plt.show()

# %%
# 'North' wind has maximum direction at 3am followed by South East.
# NNW has minimum wind direction at 3am followed by SSW.

# %%
sns.countplot(x='RainToday',data=data)
plt.show()

# %%
# Maximum record show that RainToday has 'No'. It means Rain Today has more No. It mean there is rain in today.
# Very Few chance are having that Rain will come.

# %%
sns.countplot(x='RainTomorrow',data=data)
plt.show()

# %%
# Maximum record show that RainTomorrow has 'No'. It means Rain will fall tomorrow having very less chance.
# Very Few chance are having that Rain will come tomorrow.

# %%
# Distribution plot for the column Temp3pm
sns.distplot(data["Temp3pm"],color="b",kde_kws={"shade": True},)
plt.show()

# %%
# Temp3pm is normaly distributed. But It haslittle right skewed.
# Maximum Temp3pm fall in the range of 15 to 25. After that is seem to have outliers.

# %%
#  Bivariate Analysis

# %%
sns.countplot(y='Location',hue='RainTomorrow',data=data)
plt.show()

# %%
# In Melbourne location where has maximum chance that tomorrow there is no rainfall. But Comapring to others where tomorrow having rainfall.
# Darivin has lowest chance where tomorrow rain wiill comes.

# %%
sns.barplot(x='MinTemp',y='RainTomorrow',data=data,)
plt.show()

# %%
# According to Min temperature, tomorrow have a chance that rainfall may possible. But at same parameter is say there also having chance that tomorrow no rainfalls.
# But both prediction almost near to each others.

# %%
sns.barplot(x='MaxTemp',y='RainTomorrow',data=data)
plt.show()

# %%
# By according to Max Temp tomorrow has lowest chance for rainfall. But both prediction almost near to each others.
# So maximum Temperature has 22.

# %%
sns.barplot(x='Rainfall',y='RainTomorrow',data=data)
plt.show()

# %%
# We can see, It show that tomorrow has maximum chance of rainfall.
# Upt 7 mm rainfall may possible.

# %%
sns.barplot(x='Evaporation',y='RainTomorrow',data=data)
plt.show()

# %%
# According to Evaporation. Tomorrow has comparatively low chance for rainfalls.
# Upto 5 mm Evaporation will be tomorrow.

# %%
sns.catplot(x='RainTomorrow',y='Sunshine',data=data)
plt.show()

# %%
# According to sunshine, tomorrow have comparativley high chnace for no rainfall. It means tomorrow will be no rainfall. Sky will be clean.
# But comapring to Yes, It may have chance that, tomorrow will rain comes.

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='WindGustDir', hue='RainTomorrow',data=data,palette='rocket')
plt.show()

# %%
# We can see, Wind Gust direction shows that North direction wind may flow. and due to this no rainfall tomorrow. And It has maximum chance that there is no rainfall tomorrow.
# Similarly, By same wind it also show it might have a chance that there is some rainfall tomorrow. But comapring to no Rainfall it has very less chance to right. So it strongly possible that no rainfalls tomorrow by seen plot.

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='WindDir9am', hue='RainTomorrow',data=data,palette='ocean')
plt.show()

# %%
# Wind direction At 9am will be North.Because it show maximum possibility than others. And it also show there is no rainfall tomorroww.
# Very less chance will have for rainfall.

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='WindDir3pm', hue='RainTomorrow',data=data,palette='summer')
plt.show()

# %%
# We can see, At 3 am Wind direction may be SouthEast. It has maximum possibility that there is mo rainfall tomorrow.
# But at same time North wind direction also have more posssiblity that wind will flow tomorrow in North direction.
# According to graph there is no rainfall tomorrow.

# %%
sns.catplot(x='RainTomorrow',y='WindGustSpeed',data=data)
plt.show()

# %%
# According to Wind gun speed, There are having maximum chance of rainfall tomorrow. But at same time its show also no rainfall tomorrow.
# Because both are having almost same proportion so that possibilities also in same proportion.

# %%
sns.catplot(x='RainTomorrow',y='WindSpeed9am',data=data)
plt.show()

# %%
# The maximum wind speed at 9 am are > 60. It shows that wind speed will > 60 but possibility for rainfall also low.
# But at same time, it show strong posibilities that, there is rainfall tomorrow.

# %%
sns.catplot(x='RainTomorrow',y='Humidity9am',data=data)
plt.show()

# %%
# according to Humidity9am, it show humidity at 9 am will be or almost 100. so possibility so rainfall is high in tomorrow.

# %%
sns.catplot(x='RainTomorrow',y='Pressure9am',data=data)
plt.show()

# %%
# At 9 am the presure will be more than 1000 hpa so due this there is more possobility that there is no rainfall tomorrow.
# But at Same pressure it seem that it has some possibilities that there is rainfall tomorrow.

# %%
sns.barplot(x='RainTomorrow',y='Cloud9am',data=data,palette='winter')
plt.show()

# %%
# According to Cloud at 9 am it seem that, there is huge possibilities that there will be rainfall tomorrow.
# Fraction of sky obscured is minimum 4 tomorrow.

# %%
sns.barplot(x='RainTomorrow',y='Temp9am',data=data,palette='winter')
plt.show()

# %%
# According to Temp at 9 am is having both possibilities equally that rainfall may be or may not be possible.
# Average temp is more than 17.5 degree C.

# %%
sns.scatterplot(x='MinTemp',y='MaxTemp',data=data)
plt.show()

# %%
# We can see, both features are having linear relationship with eachothers.
# As MinTem drop while MaxTemp increases.

# %%
sns.scatterplot(x='Rainfall',y='Evaporation',data=data)
plt.show()

# %%
# There is no direct relationship betweem rainfall and evaporation.
# Maximum evaporation with respect to rainfall is 60. Whereas maximum rianfall with repect to evaporation is 150.

# %%
sns.lineplot(x='Sunshine',y='Evaporation',data=data, color='g')
plt.show()

# %%
# We can see, there is linear relation with each other.
# As Sunshine is increases then Evaporation also increases.

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=data,x='Sunshine',y='Rainfall',color='green')
plt.show()

# %%
# Here we can see the Sunshine is inversely proportional to Rainfall

# %%
sns.lineplot(x='WindSpeed9am',y='WindSpeed3pm',data=data)
# Out:
# <AxesSubplot:xlabel='WindSpeed9am', ylabel='WindSpeed3pm'>

# %%
# we can see, Noth features are having linear relationship with each others.
# As Wind speed at 9 increase then wind speed at 3 also increases.

# %%
sns.lineplot(x='Pressure9am',y='Pressure3pm',data=data)
plt.show()

# %%
# We can see, pressure at 9 am has linear relation with pressure at 3 am.
# And both fetures are having positively relationship.

# %%
sns.lineplot(x='Cloud9am',y='Cloud3pm',data=data)
plt.show()

# %%
# We can see, Cloud at 9 am has linear relation with cloud at 3 pm.
# Both are positively correlated. It means that whatever type of cloud at 9 am similar type of cloud may be in 3 pm.

# %%
sns.lineplot(x='Humidity9am',y='Humidity3pm',data=data)
plt.show()

# %%
# As we know that, humidity increase then possibility of rainfall also increases.
# As per grapth both feartures are having linear relationship with each others.
# It means as humidity at 9 as same range of humidity at 3 pm.

# %%
sns.countplot(x='month', hue='RainTomorrow',data=data)
plt.show()

# %%
# May has maximum possibility of no rainfall. Bwecause the sky is completelty clean in this month and humidity may low so that, no or poor humidity due to this no rainfall in this month.
# But in july has high chance of precipitation.

# %%
sns.countplot(x='year',hue='RainTomorrow',data=data, palette='rocket')
plt.show()

# %%
# In 2010 there is high rainfall than others year. Bu we can observed here precipitation rate is decreasing.
# Due to this prediction of rainfall also decreasing.

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Cloud9am',hue='RainTomorrow',data=data, palette='winter')
plt.show()

# %%
# At Cloud 5 has maximum no rainfall and at 8 cloud has highest rainfall than others.

# %%
sns.catplot(y='Location',x='Rainfall',data=data)
plt.show()

# %%
# From above we can see, CoffdHarbour has maximum rainfall than others.
# Whereas Uluru has lowest rainfalls than others.

# %%
#  Multivariate Analysis

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='WindDir3pm', y='Sunshine',hue='RainTomorrow',data=data,palette='gnuplot')
plt.show()

# %%
# Average sunshine will be tomorrow is 5. Where East has maximum chance that tomorrow will be East direction of wind.
# Similary, according to graph it has low chance for rainfall.

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='WindDir3pm', y='WindGustSpeed',hue='RainTomorrow',data=data,palette='rocket')
plt.show()

# %%
# We can see, West direction of wind it has maximum chance of wind direction but possibilities between Yes and No has close. But Wind speed for all direction is more than 38 km/hr.
# So rainfall may come or may not come.

# %%
sns.scatterplot(x='MinTemp',y='MaxTemp',hue='RainTomorrow',data=data)
plt.show()

# %%
# It has show that, both are having linear relation ship But No rainfall has maximum than rainfall.

# %%
sns.scatterplot(x='Pressure9am',y='Pressure3pm',data=data, hue='RainTomorrow')
plt.show()

# %%
# We can see, both features are having relationship, But there is no rainfall tomorrow. It has maximum posibilities comparing to others.

# %%
sns.catplot(x='month',y='Humidity9am',hue='RainTomorrow',data=data)
plt.show()

# %%
# Humidity is more than 80 in all month. But depending on humidity it does not have a chance of rainfall.
# No rainfall is maximum than Yes rainfall.

# %%
sns. barplot(x='month',y='WindGustSpeed',hue='RainTomorrow',data=data,palette='winter')
plt.show()

# %%
# From 5 month to onwords has incresing wind speed. So due to this rainfall chance also increses.
# We can see, all month are having more than 35 kh/hr wind speed.

# %%
sns. barplot(x='year',y='WindGustSpeed',hue='RainTomorrow',data=data,palette='winter')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(y='Location',x='Sunshine',hue='RainTomorrow',data=data,palette='ocean')
plt.show()

# %%
# We can see, In Darwin station or near by darwin station sunshine is high and so that is show possibility of rainfall is low.
# But in Wollongong location sunshine is comparitively lower than Darwin location so it show strong possibility of rainfall tomorrow.

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Location',y='Temp9am', hue='RainTomorrow',data=data, palette = 'rocket')
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Temp9am'>

# %%
# In Darwin location temperature at 9 am is high so that posibility of rainfall is also high.
# Similarly In Uluru location posibility of temperature is lower than other so posibility of rainfall also low.

# %%
sns.barplot(x='year',y='Temp9am', hue='RainTomorrow',data=data, palette = 'winter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='Temp9am'>

# %%
# In 2012, temperature at 9 am is more than 22 degree c and it also have high rainfall in that year.
# In 2010 temp is lower than other and rainfall also lower than others.

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Location',y='WindGustSpeed', hue='RainTomorrow',data=data, palette = 'hsv')
# Out:
# <AxesSubplot:xlabel='Location', ylabel='WindGustSpeed'>

# %%
# We can see, Melbourme has maximum wind speed than others ans it also hgave higher chance of precipitation.
# But ta same Brisbane has lower speed of wind and it also has low chance of rainfalls.
# We can see, average wind speed for all location is more than 25 km/hr.

# %%
sns.barplot(y='Location',x='Rainfall',data=data,hue='RainTomorrow')
plt.show()

# %%
# We can see, Darwin has maximum chance to rainfalls it has also has maximum higher mm in rainfall than others.
# But lowest rainfall in PerthAirport location where rainfall quantit lower than others approximatetly upto 5.

# %%
# Encoding of Data

# %%
data.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6     5.389395  7.632205           W
# 1   Albury      7.4     25.1       0.0     5.389395  7.632205         WNW
# 2   Albury     12.9     25.7       0.0     5.389395  7.632205         WSW
# 3   Albury      9.2     28.0       0.0     5.389395  7.632205          NE
# 4   Albury     17.5     32.3       1.0     5.389395  7.632205           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  Cloud3pm  \
# 0           44.0          W        WNW  ...       1007.1  8.000000  4.503183
# 1           44.0        NNW        WSW  ...       1007.8  4.566622  4.503183
# 2           46.0          W        WSW  ...       1008.7  4.566622  2.000000
# 3           24.0         SE          E  ...       1012.8  4.566622  4.503183
# 4           41.0        ENE         NW  ...       1006.0  7.000000  8.000000
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 0     16.9     21.8         No            No  2008     12    1
# 1     17.2     24.3         No            No  2008     12    2
# 2     21.0     23.2         No            No  2008     12    3
# 3     18.1     26.5         No            No  2008     12    4
# 4     17.8     29.7         No            No  2008     12    5
#
# [5 rows x 25 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_cols=("Location","WindGustDir","WindDir9am","WindDir3pm",'WindDir3pm',"RainToday",'RainTomorrow')
for i in df_cols:
    data[i]=le.fit_transform(data[i])

# %%
data.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         1     13.4     22.9       0.6     5.389395  7.632205           13
# 1         1      7.4     25.1       0.0     5.389395  7.632205           14
# 2         1     12.9     25.7       0.0     5.389395  7.632205           15
# 3         1      9.2     28.0       0.0     5.389395  7.632205            4
# 4         1     17.5     32.3       1.0     5.389395  7.632205           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0           44.0          13          14  ...       1007.1  8.000000
# 1           44.0           6          15  ...       1007.8  4.566622
# 2           46.0          13          15  ...       1008.7  4.566622
# 3           24.0           9           0  ...       1012.8  4.566622
# 4           41.0           1           7  ...       1006.0  7.000000
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 0  4.503183     16.9     21.8          0             0  2008     12    1
# 1  4.503183     17.2     24.3          0             0  2008     12    2
# 2  2.000000     21.0     23.2          0             0  2008     12    3
# 3  4.503183     18.1     26.5          0             0  2008     12    4
# 4  8.000000     17.8     29.7          0             0  2008     12    5
#
# [5 rows x 25 columns]

# %%
#  Describe the Dataset

# %%
data.describe()
# Out:
#           Location      MinTemp      MaxTemp     Rainfall  Evaporation  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean      5.793591    13.193305    23.859976     2.805913     5.389395
# std       3.162654     5.379488     6.114516    10.309308     3.852004
# min       0.000000    -2.000000     8.200000     0.000000     0.000000
# 25%       3.000000     9.300000    19.300000     0.000000     4.000000
# 50%       6.000000    13.200000    23.300000     0.000000     5.389395
# 75%       8.000000    17.300000    28.000000     1.400000     5.389395
# max      11.000000    28.500000    45.500000   371.000000   145.000000
#
#           Sunshine  WindGustDir  WindGustSpeed   WindDir9am   WindDir3pm  ...  \
# count  8425.000000  8425.000000    8425.000000  8425.000000  8425.000000  ...
# mean      7.632205     7.217804      40.174469     7.267418     7.591098  ...
# std       2.825451     4.702616      13.776101     4.588045     4.513596  ...
# min       0.000000     0.000000       7.000000     0.000000     0.000000  ...
# 25%       7.632205     3.000000      31.000000     3.000000     3.000000  ...
# 50%       7.632205     7.000000      40.174469     7.000000     8.000000  ...
# 75%       8.900000    12.000000      48.000000    12.000000    11.000000  ...
# max      13.900000    15.000000     107.000000    15.000000    15.000000  ...
#
#        Pressure3pm     Cloud9am     Cloud3pm      Temp9am      Temp3pm  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean   1015.236075     4.566622     4.503183    17.762015    22.442934
# std       6.217451     2.429205     2.299419     5.608301     5.945849
# min     982.900000     0.000000     0.000000     1.900000     7.300000
# 25%    1011.400000     3.000000     3.000000    13.800000    18.100000
# 50%    1015.236075     4.566622     4.503183    17.762015    22.000000
# 75%    1018.800000     7.000000     7.000000    21.900000    26.300000
# max    1036.000000     8.000000     8.000000    39.400000    44.100000
#
#          RainToday  RainTomorrow         year        month          day
# count  8425.000000   8425.000000  8425.000000  8425.000000  8425.000000
# mean      0.236202      0.236320  2012.102433     6.442136    15.741958
# std       0.424773      0.424846     2.473137     3.437994     8.787354
# min       0.000000      0.000000  2008.000000     1.000000     1.000000
# 25%       0.000000      0.000000  2010.000000     3.000000     8.000000
# 50%       0.000000      0.000000  2011.000000     6.000000    16.000000
# 75%       0.000000      0.000000  2014.000000     9.000000    23.000000
# max       1.000000      1.000000  2017.000000    12.000000    31.000000
#
# [8 rows x 25 columns]

# %%
# Outcome of describe of datasets:
# Difference between 75% and max in RainFall, Evaporation and WindGustSpeed is high, columns is considerable indicating presence of outliers.
# In some features Mean to Standrad of deviation difference is close.
# In Presure9am and Pressure3pm has mean and std difference is more.

# %%
# Correlation of the features with target column

# %%
data.corr()['RainTomorrow'].sort_values()
# Out:
# Sunshine        -0.327731
# Temp3pm         -0.193805
# Pressure9am     -0.163985
# MaxTemp         -0.152886
# Pressure3pm     -0.135242
# Evaporation     -0.059012
# Temp9am         -0.023211
# day             -0.015461
# year            -0.011066
# month           -0.001243
# Location         0.002824
# WindDir3pm       0.004217
# WindDir9am       0.032860
# WindGustDir      0.051832
# WindSpeed3pm     0.053568
# WindSpeed9am     0.068285
# MinTemp          0.092942
# WindGustSpeed    0.190127
# Rainfall         0.220021
# Humidity9am      0.271222
# Cloud9am         0.278943
# RainToday        0.312929
# Cloud3pm         0.344369
# Humidity3pm      0.444808
# RainTomorrow     1.000000
# Name: RainTomorrow, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot=True, fmt ='.2f')
plt.show()

# %%
# Outcome of Correlation
# MaxTemp has 15% negative correlation with target column.
# Sunshine has 33% positive correlation with target column.
# Humidity9am has 27% positive correlation with target column.
# Humidity3pm has 44% positive correlation with target column.
# Cloud9am has 28% positive correlation with target columns.
# Cloud3pm has 34% positive correlation with target column.
# RainToday has 31% positive correlation with target column.

# %%
# Features correlation to each other
# MinTemp has 69% positive correlation with Temp3pm.
# MinTemp has 89% positive correlation with Temp9am.
# MaxTemp has 97% positive correlation with Temp3pm.
# MaxTemp has 87% positive correlation with Temp9am.
# Temp9am has 87% positive correlation with Temp3pm.
# Cloud9am has 57% positive correlation with Cloud3pm.

# %%
# Visualizing correlation of feature columns with label column

# %%
plt.figure(figsize = (20,8))
data.corr()['RainTomorrow'].sort_values(ascending = False).drop(['RainTomorrow']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('RainTomorrow',fontsize=15)
plt.title('correlation',fontsize = 18)
plt.show()

# %%
# It is observed that Humidity3pm, Cloud3pm RainToday and Cloud9am have the highest positive correlation with RainTomorrow.
# While Sunshine, Temp3pm and Pressure3pm have the highest negative correlation with RainTomorrow.

# %%
# Checking Distribution of data

# %%
data.shape
# Out:
# (8425, 25)

# %%
plt.figure(figsize=(25,30))
plotnumber = 1

# %%
for column in data:
    if plotnumber <=25:
        ax = plt.subplot(5,5,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %%
# We can see, MinTemp, MAxTemp, Humidity3pm, Pressure9am, Temp9am and Temp3pm it seem to normaly distributed.
# WindSpeed9am and WindSpeed3pm has right skewness
# All categorical features are having some skewness.

# %%
data.skew()
# Out:
# Location         -0.050456
# MinTemp          -0.089989
# MaxTemp           0.380654
# Rainfall         13.218403
# Evaporation      14.023948
# Sunshine         -0.716525
# WindGustDir       0.119640
# WindGustSpeed     0.757000
# WindDir9am        0.172792
# WindDir3pm       -0.012324
# WindSpeed9am      0.960591
# WindSpeed3pm      0.494217
# Humidity9am      -0.256743
# Humidity3pm       0.118281
# Pressure9am      -0.024082
# Pressure3pm      -0.010214
# Cloud9am         -0.366503
# Cloud3pm         -0.276294
# Temp9am          -0.014748
# Temp3pm           0.397331
# RainToday         1.242362
# RainTomorrow      1.241588
# year              0.418663
# month             0.039388
# day               0.004260
# dtype: float64

# %%
# Outcome of the skewness: Skewness threshold is taken is +/-0.65.
# RainFall, Evaporation, WindSpeed9am and RainToday are having skewness.

# %%
# Checking Outliers

# %%
plt.figure(figsize=(25,30))
plotnumber = 1

for column in data:
    if plotnumber <=25:
        plt.subplot(5,5,plotnumber)
        ax = sns.boxplot(data=data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %%
# MaxTemp, Rainfall, Evaporation, Sunshine, WindGustSpeed, WindSpeed9am, WindSpeed3pm, Humidity9am, Pressure9am, Pressure3pm, Temppam and Temp3pm are having a more Outliers.
# Some feature are not having outliers but those are categorical features.

# %%
# Removing Outliers

# %%
data.head(2)
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         1     13.4     22.9       0.6     5.389395  7.632205           13
# 1         1      7.4     25.1       0.0     5.389395  7.632205           14
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0           44.0          13          14  ...       1007.1  8.000000
# 1           44.0           6          15  ...       1007.8  4.566622
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 0  4.503183     16.9     21.8          0             0  2008     12    1
# 1  4.503183     17.2     24.3          0             0  2008     12    2
#
# [2 rows x 25 columns]

# %%
from scipy.stats import zscore

z_score = zscore(data[['MaxTemp','Rainfall','Evaporation','Sunshine','WindGustSpeed','WindSpeed9am','WindSpeed3pm','Humidity9am','Pressure9am','Pressure3pm','Temp9am','Temp3pm']])
abs_z_score = np.abs(z_score)    # Apply the formula and get the scaled data

filtering_entry = (abs_z_score  < 3).all(axis=1)

df = data[filtering_entry]

# %%
df.shape
# Out:
# (7987, 25)

# %%
data.shape
# Out:
# (8425, 25)

# %%
# Percentage of data loss

# %%
data_loss = ((8425 - 7987)/8425*100)
print(data_loss,'%')
# Out:
# 5.198813056379822 %

# %%
# Data skewness before removing

# %%
data.skew()
# Out:
# Location         -0.050456
# MinTemp          -0.089989
# MaxTemp           0.380654
# Rainfall         13.218403
# Evaporation      14.023948
# Sunshine         -0.716525
# WindGustDir       0.119640
# WindGustSpeed     0.757000
# WindDir9am        0.172792
# WindDir3pm       -0.012324
# WindSpeed9am      0.960591
# WindSpeed3pm      0.494217
# Humidity9am      -0.256743
# Humidity3pm       0.118281
# Pressure9am      -0.024082
# Pressure3pm      -0.010214
# Cloud9am         -0.366503
# Cloud3pm         -0.276294
# Temp9am          -0.014748
# Temp3pm           0.397331
# RainToday         1.242362
# RainTomorrow      1.241588
# year              0.418663
# month             0.039388
# day               0.004260
# dtype: float64

# %%
# Data skewness after removing Outliers

# %%
df.skew()
# Out:
# Location        -0.040284
# MinTemp         -0.084549
# MaxTemp          0.314510
# Rainfall         3.488446
# Evaporation      0.846181
# Sunshine        -0.723970
# WindGustDir      0.112339
# WindGustSpeed    0.506897
# WindDir9am       0.160081
# WindDir3pm      -0.014739
# WindSpeed9am     0.711395
# WindSpeed3pm     0.300109
# Humidity9am     -0.231656
# Humidity3pm      0.125150
# Pressure9am      0.020735
# Pressure3pm      0.044876
# Cloud9am        -0.356892
# Cloud3pm        -0.266829
# Temp9am         -0.038035
# Temp3pm          0.334170
# RainToday        1.301170
# RainTomorrow     1.296077
# year             0.430100
# month            0.054460
# day              0.002731
# dtype: float64

# %%
df.plot(kind='density', subplots=True, layout=(5,5), sharex=False, legend=True, fontsize=1, figsize=(22,12))
plt.show()

# %%
# can see, data is little nornally distributed after removing skewness.

# %%
# Checking Multicollinearity

# %%
x = df.drop(columns=['RainTomorrow'],axis=1)
y = df['RainTomorrow']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#          Features        vif
# 0        Location   1.571124
# 1         MinTemp   8.795820
# 2         MaxTemp  26.460462
# 3        Rainfall   1.955499
# 4     Evaporation   1.542562
# 5        Sunshine   1.939800
# 6     WindGustDir   1.649083
# 7   WindGustSpeed   2.310613
# 8      WindDir9am   1.353548
# 9      WindDir3pm   1.525591
# 10   WindSpeed9am   2.018982
# 11   WindSpeed3pm   1.973231
# 12    Humidity9am   3.972911
# 13    Humidity3pm   5.394939
# 14    Pressure9am  19.761925
# 15    Pressure3pm  18.950421
# 16       Cloud9am   1.922867
# 17       Cloud3pm   1.807330
# 18        Temp9am  17.656891
# 19        Temp3pm  33.356045
# 20      RainToday   2.136867
# 21           year   1.509700
# 22          month   1.153304
# 23            day   1.004197

# %%
# If VIF > 10, It means multicollinearity is present.
# MultiCollinearity are exists in MaxTemp, Pressure9am, Pressure3pm, Temp9am and Temp3pm. Based on ANOVA F scores.

# %%
# Droping columns whose having multicollinearity

# %%
df.drop(columns=['MaxTemp','Pressure9am','Pressure3pm','Temp9am','Temp3pm'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Location  MinTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         1     13.4       0.6     5.389395  7.632205           13
# 1         1      7.4       0.0     5.389395  7.632205           14
# 2         1     12.9       0.0     5.389395  7.632205           15
# 3         1      9.2       0.0     5.389395  7.632205            4
# 4         1     17.5       1.0     5.389395  7.632205           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          13          14          20.0          24.0
# 1           44.0           6          15           4.0          22.0
# 2           46.0          13          15          19.0          26.0
# 3           24.0           9           0          11.0           9.0
# 4           41.0           1           7           7.0          20.0
#
#    Humidity9am  Humidity3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow  \
# 0         71.0         22.0  8.000000  4.503183          0             0
# 1         44.0         25.0  4.566622  4.503183          0             0
# 2         38.0         30.0  4.566622  2.000000          0             0
# 3         45.0         16.0  4.566622  4.503183          0             0
# 4         82.0         33.0  7.000000  8.000000          0             0
#
#    year  month  day
# 0  2008     12    1
# 1  2008     12    2
# 2  2008     12    3
# 3  2008     12    4
# 4  2008     12    5

# %%
x = df.drop(columns=['RainTomorrow'],axis=1)
y = df['RainTomorrow']

# %%
df.shape
# Out:
# (7987, 20)

# %%
data.shape
# Out:
# (8425, 25)

# %%
#  Data Skewness before removing

# %%
data.skew()
# Out:
# Location         -0.050456
# MinTemp          -0.089989
# MaxTemp           0.380654
# Rainfall         13.218403
# Evaporation      14.023948
# Sunshine         -0.716525
# WindGustDir       0.119640
# WindGustSpeed     0.757000
# WindDir9am        0.172792
# WindDir3pm       -0.012324
# WindSpeed9am      0.960591
# WindSpeed3pm      0.494217
# Humidity9am      -0.256743
# Humidity3pm       0.118281
# Pressure9am      -0.024082
# Pressure3pm      -0.010214
# Cloud9am         -0.366503
# Cloud3pm         -0.276294
# Temp9am          -0.014748
# Temp3pm           0.397331
# RainToday         1.242362
# RainTomorrow      1.241588
# year              0.418663
# month             0.039388
# day               0.004260
# dtype: float64

# %%
# Data Skewness After Removing

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
trans = pd.DataFrame(x)

# %%
trans.skew()
# Out:
# 0    -0.184130
# 1    -0.104134
# 2     0.913570
# 3     0.074744
# 4    -0.066262
# 5    -0.190268
# 6     0.003128
# 7    -0.160087
# 8    -0.221155
# 9    -0.111481
# 10   -0.076708
# 11   -0.063948
# 12   -0.036039
# 13   -0.280736
# 14   -0.218724
# 15    1.301170
# 16    0.000000
# 17   -0.149530
# 18   -0.213217
# dtype: float64

# %%
# Building Model for Predicting RainTomorrow(Classification)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier

# %%
from sklearn.preprocessing import StandardScaler

# transform my dataset into standard normal distribution
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-1.56842088,  0.06050157,  0.61739644, ..., -1.66757678,
#          1.52402297, -1.8856122 ],
#        [-1.56842088, -1.05725282, -0.69366959, ..., -1.66757678,
#          1.52402297, -1.70313123],
#        [-1.56842088, -0.03222196, -0.69366959, ..., -1.66757678,
#          1.52402297, -1.53666415],
#        ...,
#        [ 1.01632853, -1.43299533, -0.69366959, ...,  1.99906255,
#         -0.04671799,  0.83621705],
#        [ 1.01632853, -0.98233371, -0.69366959, ...,  1.99906255,
#         -0.04671799,  0.93461949],
#        [ 1.01632853,  0.33829567, -0.69366959, ...,  1.99906255,
#         -0.04671799,  1.03196621]])

# %%
# Balancing the Data

# %%
from imblearn.over_sampling import SMOTE as sm

smt_x,smt_y = sm().fit_resample(x,y)

# %%
smt_y.value_counts()
# Out:
# 0    6165
# 1    6165
# Name: RainTomorrow, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(smt_x, smt_y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (8631, 19)
# Training target vector size: (8631,)
# Test feature matrix size: (3699, 19)
# Test target vector size: (3699,)

# %%
#  LogisticRegression
# Finding Best Random State
# Finding Best Random Stat

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(smt_x,smt_y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.7880508245471749 on Random_state 229

# %%
X_train, X_test, Y_train, Y_test = train_test_split(smt_x, smt_y, random_state=71, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.7793998377939984
#
#
# Confusion matrix of Logistics Regression :
#  [[1490  390]
#  [ 426 1393]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79      1880
#            1       0.78      0.77      0.77      1819
#
#     accuracy                           0.78      3699
#    macro avg       0.78      0.78      0.78      3699
# weighted avg       0.78      0.78      0.78      3699

# %%
# Finding Optimal value of n_neighbors for KNN

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.29595817420019405
# RMSE value for k=  2 is: 0.29412559822593703
# RMSE value for k=  3 is: 0.3672891567720814
# RMSE value for k=  4 is: 0.36022881797219947
# RMSE value for k=  5 is: 0.3866521237861393
# RMSE value for k=  6 is: 0.3810175474328495
# RMSE value for k=  7 is: 0.405757429564008
# RMSE value for k=  8 is: 0.3963199190519718
# RMSE value for k=  9 is: 0.41530596960729704
# RMSE value for k=  10 is: 0.40375367692464464
# RMSE value for k=  11 is: 0.4117101792463392
# RMSE value for k=  12 is: 0.4080827060764132
# RMSE value for k=  13 is: 0.419193473737245
# RMSE value for k=  14 is: 0.4133485071646401
# RMSE value for k=  15 is: 0.42527601837935436
# RMSE value for k=  16 is: 0.4198378914485589
# RMSE value for k=  17 is: 0.4274951405113914
# RMSE value for k=  18 is: 0.42559374424988167
# RMSE value for k=  19 is: 0.434084444800348
# RMSE value for k=  20 is: 0.432212037316646

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(20), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %%
# At k=1, we get the minimum RMSE value which approximately 0.282880942212237, and shoots up on further increasing the k value. We can safely say that k=1 will give us the best result in this case

# %%
# Applying other classification algorithm

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix LogisticRegression() is
#
#
# Accuracy Score :
#  0.7793998377939984
#
#
# Confusion matrix :
#  [[1490  390]
#  [ 426 1393]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79      1880
#            1       0.78      0.77      0.77      1819
#
#     accuracy                           0.78      3699
#    macro avg       0.78      0.78      0.78      3699
# weighted avg       0.78      0.78      0.78      3699
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.8483373884833739
#
#
# Confusion matrix :
#  [[1553  327]
#  [ 234 1585]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      1880
#            1       0.83      0.87      0.85      1819
#
#     accuracy                           0.85      3699
#    macro avg       0.85      0.85      0.85      3699
# weighted avg       0.85      0.85      0.85      3699
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.7456069207894025
#
#
# Confusion matrix :
#  [[1413  467]
#  [ 474 1345]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75      1880
#            1       0.74      0.74      0.74      1819
#
#     accuracy                           0.75      3699
#    macro avg       0.75      0.75      0.75      3699
# weighted avg       0.75      0.75      0.75      3699
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.8799675587996756
#
#
# Confusion matrix :
#  [[1635  245]
#  [ 199 1620]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      1880
#            1       0.87      0.89      0.88      1819
#
#     accuracy                           0.88      3699
#    macro avg       0.88      0.88      0.88      3699
# weighted avg       0.88      0.88      0.88      3699
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier(n_neighbors=3) is
#
#
# Accuracy Score :
#  0.8650986753176534
#
#
# Confusion matrix :
#  [[1439  441]
#  [  58 1761]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.96      0.77      0.85      1880
#            1       0.80      0.97      0.88      1819
#
#     accuracy                           0.87      3699
#    macro avg       0.88      0.87      0.86      3699
# weighted avg       0.88      0.87      0.86      3699
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.9278183292781833
#
#
# Confusion matrix :
#  [[1737  143]
#  [ 124 1695]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93      1880
#            1       0.92      0.93      0.93      1819
#
#     accuracy                           0.93      3699
#    macro avg       0.93      0.93      0.93      3699
# weighted avg       0.93      0.93      0.93      3699
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix ExtraTreesClassifier() is
#
#
# Accuracy Score :
#  0.9394430927277643
#
#
# Confusion matrix :
#  [[1742  138]
#  [  86 1733]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      1880
#            1       0.93      0.95      0.94      1819
#
#     accuracy                           0.94      3699
#    macro avg       0.94      0.94      0.94      3699
# weighted avg       0.94      0.94      0.94      3699
#
#
#
# ============================================================================================================

# %%
# CrossValidation :

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, smt_x, smt_y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('================================================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.71370641 0.64760746 0.64720195 0.73884834 0.82806164]
# Mean Score : 0.7150851581508515
# Std deviation : 0.06706958279386464
#
#
# ================================================================================================
#
#
# Cross Validation Score SVC() :
#
# Score : [0.68856448 0.64152474 0.72911598 0.77088402 0.82278994]
# Mean Score : 0.7305758313057583
# Std deviation : 0.0629688419886086
#
#
# ================================================================================================
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.72627737 0.68856448 0.64233577 0.71248986 0.79480941]
# Mean Score : 0.7128953771289538
# Std deviation : 0.04991953936244661
#
#
# ================================================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.5567721  0.67477697 0.8783455  0.82319546 0.76155718]
# Mean Score : 0.7389294403892944
# Std deviation : 0.11344289305055977
#
#
# ================================================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.70316302 0.68045418 0.79805353 0.81508516 0.7972425 ]
# Mean Score : 0.7587996755879967
# Std deviation : 0.05553418050681111
#
#
# ================================================================================================
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.6054339  0.66098946 0.88402271 0.87996756 0.81062449]
# Mean Score : 0.7682076236820763
# Std deviation : 0.11462428013979979
#
#
# ================================================================================================
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.662206   0.70316302 0.88564477 0.89618816 0.82603406]
# Mean Score : 0.7946472019464721
# Std deviation : 0.09537954270301448
#
#
# ================================================================================================

# %%
# 12. Selecting Best Model
#Based on comparing Accuracy Score results with Cross Validation results, it is determined ExtraTreesClassifier is the best model.
# 13. Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
             'max_features':['auto','sqrt','log2'],
              'min_samples_split':[3,5,8,11],
              'max_depth' : [10,20,30],
              'n_estimators' : [100,200,300,400]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 1/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.827 total time=   1.9s
# [CV 2/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 2/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.803 total time=   1.6s
# [CV 3/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 3/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.826 total time=   2.0s
# [CV 4/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 4/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.833 total time=   1.6s
# [CV 5/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 5/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.818 total time=   1.8s
# [CV 1/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 1/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.826 total time=   3.7s
# [CV 2/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 2/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.807 total time=   3.8s
# [CV 3/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 3/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.836 total time=   3.8s
# [CV 4/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 4/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.831 total time=   3.8s
# [CV 5/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 5/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.821 total time=   3.9s
# [CV 1/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 1/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.825 total time=   5.8s
# [CV 2/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 2/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.804 total time=   5.3s
# [CV 3/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 3/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.829 total time=   6.2s
# [CV 4/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 4/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.831 total time=   5.0s
# [CV 5/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 5/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.820 total time=   6.2s
# [CV 1/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 1/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.826 total time=   8.4s
# [CV 2/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 2/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.805 total time=   5.8s
# [CV 3/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 3/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.829 total time=   6.3s
# [CV 4/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 4/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.834 total time=   7.3s
# [CV 5/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 5/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.823 total time=   7.2s
# [CV 1/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 1/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.820 total time=   1.7s
# [CV 2/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 2/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.801 total time=   1.7s
# [CV 3/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 3/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.827 total time=   2.0s
# [CV 4/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 4/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.828 total time=   1.9s
# [CV 5/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 5/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.820 total time=   1.8s
# [CV 1/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 1/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.826 total time=   3.5s
# [CV 2/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 2/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.800 total time=   3.5s
# [CV 3/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 3/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.827 total time=   3.2s
# [CV 4/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 4/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.831 total time=   3.5s
# [CV 5/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 5/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.820 total time=   3.1s
# [CV 1/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 1/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.823 total time=   5.8s
# [CV 2/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 2/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.801 total time=   5.7s
# [CV 3/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 3/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.829 total time=   4.6s
# [CV 4/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 4/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.834 total time=   4.9s
# [CV 5/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 5/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.816 total time=   5.2s
# [CV 1/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 1/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.824 total time=   7.1s
# [CV 2/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 2/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.798 total time=   7.0s
# [CV 3/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 3/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.825 total time=   7.4s
# [CV 4/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 4/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.832 total time=   7.7s
# [CV 5/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 5/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.816 total time=   7.4s
# [CV 1/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 1/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.813 total time=   1.8s
# [CV 2/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 2/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.794 total time=   1.7s
# [CV 3/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 3/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.821 total time=   1.9s
# [CV 4/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 4/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.830 total time=   1.7s
# [CV 5/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 5/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.816 total time=   1.8s
# [CV 1/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 1/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.820 total time=   3.7s
# [CV 2/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 2/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.797 total time=   3.7s
# [CV 3/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 3/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.824 total time=   3.5s
# [CV 4/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 4/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.827 total time=   3.7s
# [CV 5/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 5/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.815 total time=   3.8s
# [CV 1/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 1/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.817 total time=   5.3s
# [CV 2/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 2/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.797 total time=   5.4s
# [CV 3/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 3/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.820 total time=   5.1s
# [CV 4/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 4/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.831 total time=   4.3s
# [CV 5/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 5/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.820 total time=   5.3s
# [CV 1/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 1/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.823 total time=   7.2s
# [CV 2/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 2/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.799 total time=   7.6s
# [CV 3/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 3/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.820 total time=   7.8s
# [CV 4/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 4/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.831 total time=   7.4s
# [CV 5/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 5/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.814 total time=   7.3s
# [CV 1/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 1/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.816 total time=   1.6s
# [CV 2/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 2/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.801 total time=   1.7s
# [CV 3/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 3/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.819 total time=   1.7s
# [CV 4/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 4/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.830 total time=   1.8s
# [CV 5/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 5/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.811 total time=   1.9s
# [CV 1/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 1/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.818 total time=   3.6s
# [CV 2/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 2/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.799 total time=   3.7s
# [CV 3/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 3/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.818 total time=   3.7s
# [CV 4/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 4/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.829 total time=   3.5s
# [CV 5/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 5/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.814 total time=   3.5s
# [CV 1/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 1/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.818 total time=   5.5s
# [CV 2/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 2/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.800 total time=   5.4s
# [CV 3/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 3/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.816 total time=   5.5s
# [CV 4/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 4/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.829 total time=   5.4s
# [CV 5/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 5/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.817 total time=   5.6s
# [CV 1/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 1/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.819 total time=   7.2s
# [CV 2/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 2/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.797 total time=   7.3s
# [CV 3/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 3/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.815 total time=   7.3s
# [CV 4/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 4/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.831 total time=   7.2s
# [CV 5/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 5/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.817 total time=   8.0s
# [CV 1/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 1/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.822 total time=   1.8s
# [CV 2/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 2/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.801 total time=   1.8s
# [CV 3/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 3/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.820 total time=   1.7s
# [CV 4/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 4/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.836 total time=   1.9s
# [CV 5/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 5/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.827 total time=   1.7s
# [CV 1/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 1/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.822 total time=   3.6s
# [CV 2/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 2/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.800 total time=   3.7s
# [CV 3/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 3/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.831 total time=   3.8s
# [CV 4/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 4/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.838 total time=   3.5s
# [CV 5/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 5/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.819 total time=   3.8s
# [CV 1/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 1/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.826 total time=   5.6s
# [CV 2/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 2/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.802 total time=   5.7s
# [CV 3/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 3/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.829 total time=   5.7s
# [CV 4/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 4/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.835 total time=   5.4s
# [CV 5/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 5/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.823 total time=   5.7s
# [CV 1/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 1/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.822 total time=   7.5s
# [CV 2/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 2/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.805 total time=   7.7s
# [CV 3/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 3/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.835 total time=   7.4s
# [CV 4/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 4/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.834 total time=   7.3s
# [CV 5/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 5/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.819 total time=   7.5s
# [CV 1/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 1/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.815 total time=   1.6s
# [CV 2/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 2/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.798 total time=   1.8s
# [CV 3/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 3/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.819 total time=   1.8s
# [CV 4/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 4/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.831 total time=   1.7s
# [CV 5/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 5/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.823 total time=   2.0s
# [CV 1/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 1/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.826 total time=   3.7s
# [CV 2/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 2/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.805 total time=   3.6s
# [CV 3/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 3/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.826 total time=   4.0s
# [CV 4/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 4/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.830 total time=   4.5s
# [CV 5/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 5/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.822 total time=   3.7s
# [CV 1/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 1/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.825 total time=   5.6s
# [CV 2/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 2/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.802 total time=   4.4s
# [CV 3/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 3/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.828 total time=   5.1s
# [CV 4/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 4/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.830 total time=   5.6s
# [CV 5/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 5/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.820 total time=   5.4s
# [CV 1/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 1/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.826 total time=   7.2s
# [CV 2/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 2/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.801 total time=   7.4s
# [CV 3/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 3/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.826 total time=   7.4s
# [CV 4/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 4/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.831 total time=   7.7s
# [CV 5/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 5/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.820 total time=   7.4s
# [CV 1/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 1/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.816 total time=   1.7s
# [CV 2/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 2/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.797 total time=   1.7s
# [CV 3/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 3/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.824 total time=   1.8s
# [CV 4/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 4/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.830 total time=   1.9s
# [CV 5/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 5/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.813 total time=   1.7s
# [CV 1/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 1/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.826 total time=   3.7s
# [CV 2/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 2/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.797 total time=   3.5s
# [CV 3/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 3/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.823 total time=   3.6s
# [CV 4/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 4/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.834 total time=   3.9s
# [CV 5/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 5/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.816 total time=   3.6s
# [CV 1/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 1/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.816 total time=   5.5s
# [CV 2/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 2/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.798 total time=   5.5s
# [CV 3/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 3/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.820 total time=   5.4s
# [CV 4/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 4/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.829 total time=   5.6s
# [CV 5/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 5/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.818 total time=   5.3s
# [CV 1/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 1/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.822 total time=   7.3s
# [CV 2/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 2/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.799 total time=   7.5s
# [CV 3/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 3/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.829 total time=   7.2s
# [CV 4/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 4/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.831 total time=   7.3s
# [CV 5/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 5/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.820 total time=   7.2s
# [CV 1/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 1/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.815 total time=   1.8s
# [CV 2/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 2/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.794 total time=   1.8s
# [CV 3/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 3/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.821 total time=   1.5s
# [CV 4/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 4/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.827 total time=   1.5s
# [CV 5/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 5/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.816 total time=   1.5s
# [CV 1/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 1/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.814 total time=   3.9s
# [CV 2/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 2/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.790 total time=   4.0s
# [CV 3/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 3/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.815 total time=   3.7s
# [CV 4/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 4/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.831 total time=   4.1s
# [CV 5/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 5/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.813 total time=   3.5s
# [CV 1/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 1/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.821 total time=   5.6s
# [CV 2/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 2/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.795 total time=   5.1s
# [CV 3/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 3/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.816 total time=   4.9s
# [CV 4/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 4/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.828 total time=   5.5s
# [CV 5/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 5/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.815 total time=   5.5s
# [CV 1/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 1/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.820 total time=   7.2s
# [CV 2/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 2/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.801 total time=   7.4s
# [CV 3/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 3/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.820 total time=   7.4s
# [CV 4/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 4/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.831 total time=   6.6s
# [CV 5/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 5/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.811 total time=   7.1s
# [CV 1/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 1/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.819 total time=   1.7s
# [CV 2/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 2/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.808 total time=   1.9s
# [CV 3/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 3/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.827 total time=   1.8s
# [CV 4/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 4/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.834 total time=   2.0s
# [CV 5/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 5/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.819 total time=   1.8s
# [CV 1/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 1/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.824 total time=   3.7s
# [CV 2/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 2/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.803 total time=   3.5s
# [CV 3/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 3/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.820 total time=   3.9s
# [CV 4/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 4/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.833 total time=   3.5s
# [CV 5/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 5/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.822 total time=   3.5s
# [CV 1/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 1/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.825 total time=   6.0s
# [CV 2/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 2/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.804 total time=   5.7s
# [CV 3/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 3/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.831 total time=   5.6s
# [CV 4/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 4/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.832 total time=   6.0s
# [CV 5/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 5/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.820 total time=   5.7s
# [CV 1/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 1/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.830 total time=   7.6s
# [CV 2/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 2/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.806 total time=   7.6s
# [CV 3/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 3/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.828 total time=   7.6s
# [CV 4/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 4/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.832 total time=   7.4s
# [CV 5/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 5/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.818 total time=   7.3s
# [CV 1/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 1/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.826 total time=   1.7s
# [CV 2/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 2/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.805 total time=   1.7s
# [CV 3/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 3/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.826 total time=   1.8s
# [CV 4/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 4/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.830 total time=   2.0s
# [CV 5/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 5/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.824 total time=   1.8s
# [CV 1/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 1/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.821 total time=   3.5s
# [CV 2/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 2/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.802 total time=   3.5s
# [CV 3/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 3/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.827 total time=   3.8s
# [CV 4/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 4/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.827 total time=   3.7s
# [CV 5/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 5/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.820 total time=   3.4s
# [CV 1/5; 39/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 1/5; 39/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.826 total time=   5.3s
# ...
# [CV 1/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 1/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.922 total time=   2.1s
# [CV 2/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 2/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.915 total time=   2.8s
# [CV 3/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 3/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.924 total time=   2.7s
# [CV 4/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 4/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.927 total time=   2.8s
# [CV 5/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 5/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.917 total time=   2.7s
# [CV 1/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 1/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.928 total time=   5.7s
# [CV 2/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 2/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.915 total time=   5.6s
# [CV 3/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 3/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.923 total time=   5.8s
# [CV 4/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 4/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.929 total time=   5.5s
# [CV 5/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 5/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.917 total time=   5.7s
# [CV 1/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 1/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.920 total time=   8.6s
# [CV 2/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 2/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.918 total time=   8.4s
# [CV 3/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 3/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.921 total time=   8.4s
# [CV 4/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 4/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.930 total time=   8.6s
# [CV 5/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 5/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.918 total time=   8.6s
# [CV 1/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 1/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.924 total time=   9.2s
# [CV 2/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 2/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.918 total time=   8.5s
# [CV 3/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 3/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.925 total time=   9.9s
# [CV 4/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 4/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.930 total time=   9.1s
# [CV 5/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 5/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.916 total time=  11.3s
# [CV 1/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 1/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.921 total time=   2.6s
# [CV 2/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 2/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.909 total time=   2.4s
# [CV 3/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 3/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.922 total time=   2.6s
# [CV 4/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 4/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.921 total time=   2.6s
# [CV 5/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 5/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.907 total time=   2.7s
# [CV 1/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 1/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.921 total time=   5.3s
# [CV 2/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 2/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.911 total time=   5.3s
# [CV 3/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 3/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.919 total time=   5.3s
# [CV 4/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 4/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.920 total time=   5.3s
# [CV 5/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 5/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.910 total time=   5.3s
# [CV 1/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 1/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.918 total time=   8.0s
# [CV 2/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 2/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.915 total time=   8.0s
# [CV 3/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 3/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.915 total time=   7.9s
# [CV 4/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 4/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.924 total time=   8.3s
# [CV 5/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 5/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.913 total time=   6.4s
# [CV 1/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 1/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.917 total time=   6.6s
# [CV 2/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 2/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.912 total time=   6.6s
# [CV 3/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 3/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.919 total time=   9.6s
# [CV 4/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 4/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.922 total time=  10.5s
# [CV 5/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 5/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.911 total time=  10.6s
# [CV 1/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 1/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.911 total time=   2.7s
# [CV 2/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 2/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.903 total time=   2.5s
# [CV 3/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 3/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.906 total time=   2.6s
# [CV 4/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 4/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.918 total time=   2.6s
# [CV 5/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 5/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.901 total time=   2.5s
# [CV 1/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 1/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.909 total time=   5.2s
# [CV 2/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 2/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.903 total time=   5.3s
# [CV 3/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 3/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.911 total time=   5.3s
# [CV 4/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 4/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.921 total time=   5.2s
# [CV 5/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 5/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.903 total time=   5.2s
# [CV 1/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 1/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.910 total time=   7.7s
# [CV 2/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 2/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.901 total time=   8.3s
# [CV 3/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 3/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.916 total time=  10.7s
# [CV 4/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 4/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.921 total time=   8.0s
# [CV 5/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 5/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.906 total time=   6.3s
# [CV 1/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 1/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.907 total time=   6.8s
# [CV 2/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 2/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.910 total time=   6.2s
# [CV 3/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 3/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.906 total time=   7.5s
# [CV 4/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 4/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.917 total time=  15.1s
# [CV 5/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 5/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.904 total time=  12.0s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [3, 5, 8, 11],
#                          'n_estimators': [100, 200, 300, 400]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 30,
#  'max_features': 'sqrt',
#  'min_samples_split': 3,
#  'n_estimators': 300}

# %%
#  Confusion Matrix and ROC_AUC Curve

# %%
Final_mod = ExtraTreesClassifier(criterion='entropy',n_estimators= 300, max_depth=30 ,
                                 min_samples_split= 3, max_features= 'sqrt')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.9391727493917275

# %%
# Lets plot confusion matrix for  FinalModel
Matrix = confusion_matrix(Y_test, y_pred)

x_labels = ["NO","YES"]
y_labels = ["NO","YES"]

fig , ax = plt.subplots(figsize=(5,5))
sns.heatmap(Matrix, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, 
            cmap="plasma", xticklabels = x_labels, yticklabels = y_labels)

plt.xlabel("Predicted Label",fontsize=14,fontweight='bold')
plt.ylabel("True Label",fontsize=14,fontweight='bold')
plt.title('Confusion Matrix for Final Model',fontsize=20,fontweight='bold')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(Final_mod,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve of Final Model',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.9393657960300844

# %%
# Model Save

# %%
import pickle
pickle.dump(Final_mod, open('Rainfall','wb'))

# %%
#  Predicting the Rain tomorrow

# %%
# Prediction
prediction = Final_mod.predict(X_test)

# %%
Actual = np.array(Y_test)
df_Pred = pd.DataFrame()
df_Pred["Predicted Values"] = prediction
df_Pred["Actual Values"] = Actual
df_Pred.head()
# Out:
#    Predicted Values  Actual Values
# 0                 1              1
# 1                 1              0
# 2                 0              0
# 3                 0              0
# 4                 0              0

# %%
# Building Model for Predicting Rainfall (Regression)

# %%
df.head()
# Out:
#    Location  MinTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         1     13.4       0.6     5.389395  7.632205           13
# 1         1      7.4       0.0     5.389395  7.632205           14
# 2         1     12.9       0.0     5.389395  7.632205           15
# 3         1      9.2       0.0     5.389395  7.632205            4
# 4         1     17.5       1.0     5.389395  7.632205           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          13          14          20.0          24.0
# 1           44.0           6          15           4.0          22.0
# 2           46.0          13          15          19.0          26.0
# 3           24.0           9           0          11.0           9.0
# 4           41.0           1           7           7.0          20.0
#
#    Humidity9am  Humidity3pm  Cloud9am  Cloud3pm  RainToday  RainTomorrow  \
# 0         71.0         22.0  8.000000  4.503183          0             0
# 1         44.0         25.0  4.566622  4.503183          0             0
# 2         38.0         30.0  4.566622  2.000000          0             0
# 3         45.0         16.0  4.566622  4.503183          0             0
# 4         82.0         33.0  7.000000  8.000000          0             0
#
#    year  month  day
# 0  2008     12    1
# 1  2008     12    2
# 2  2008     12    3
# 3  2008     12    4
# 4  2008     12    5

# %%
df.shape
# Out:
# (7987, 20)

# %%
# Checking Multicollinearity

# %%
x = df.drop(columns=['Rainfall'],axis=1)
y = df['Rainfall']

# %%
x.shape
# Out:
# (7987, 19)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#          Features       vif
# 0        Location  1.571506
# 1         MinTemp  1.458396
# 2     Evaporation  1.496683
# 3        Sunshine  1.892046
# 4     WindGustDir  1.618959
# 5   WindGustSpeed  2.175749
# 6      WindDir9am  1.289110
# 7      WindDir3pm  1.456821
# 8    WindSpeed9am  1.898445
# 9    WindSpeed3pm  1.918344
# 10    Humidity9am  2.459093
# 11    Humidity3pm  2.308065
# 12       Cloud9am  1.848332
# 13       Cloud3pm  1.799550
# 14      RainToday  1.319670
# 15   RainTomorrow  1.421762
# 16           year  1.471638
# 17          month  1.119055
# 18            day  1.002657

# %%
# If VIF > 10, It means multicollinearity is present.
# MultiCollinearity not exists Based on ANOVA F scores.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler

# transform my dataset into standard normal distribution
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-1.56842088,  0.06050157,  0.18631083, ..., -1.66757678,
#          1.52402297, -1.8856122 ],
#        [-1.56842088, -1.05725282,  0.18631083, ..., -1.66757678,
#          1.52402297, -1.70313123],
#        [-1.56842088, -0.03222196,  0.18631083, ..., -1.66757678,
#          1.52402297, -1.53666415],
#        ...,
#        [ 1.01632853, -1.43299533,  0.18631083, ...,  1.99906255,
#         -0.04671799,  0.83621705],
#        [ 1.01632853, -0.98233371,  0.18631083, ...,  1.99906255,
#         -0.04671799,  0.93461949],
#        [ 1.01632853,  0.33829567,  0.18631083, ...,  1.99906255,
#         -0.04671799,  1.03196621]])

# %%
#  Linear Regression
# Finding Best Random State

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,250):
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, random_state=i, test_size=.25)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.5293586393703866 on Random_state 67

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=67)

# %%
regressors = {
    
    'Random Forest' : RandomForestRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results
# Out:
#                  MAE    MSE      RMSE  R2-score
# Random Forest  1.114  7.898  2.810327     0.636

# %%
# Cross - Validation of the model

# %%
y_pred = lin_reg.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(lin_reg,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 47.71859390465115
# accuracy_score is:- 52.022201166854984
#
#
# At cv:- 5
# Cross validation score is:- 48.32309646202038
# accuracy_score is:- 52.022201166854984
#
#
# At cv:- 6
# Cross validation score is:- 48.08595524331986
# accuracy_score is:- 52.022201166854984
#
#
# At cv:- 7
# Cross validation score is:- 47.99463543598289
# accuracy_score is:- 52.022201166854984
#
#
# At cv:- 8
# Cross validation score is:- 48.125471601197646
# accuracy_score is:- 52.022201166854984
#
#
# At cv:- 9
# Cross validation score is:- 48.10425252383374
# accuracy_score is:- 52.022201166854984

# %%
lsscore_selected = cross_val_score(lin_reg,x,y,cv=9).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.4810425252383374
# The accuracy score is:  0.5202220116685499

# %%
# RandomForest Regressor
# Finding Best Random State

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    rf = RandomForestRegressor()
    rf.fit(X_train, y_train)
    pred = rf.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=137)

# %%
regressors = {
    
    'Random Forest' : RandomForestRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results

# %%
# Cross - Validation of the model

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(rf,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')

# %%
lsscore_selected = cross_val_score(rf,x,y,cv=9).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)

# %%
# Gradient Boosting Regressor
# Finding Best Random State

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    gbr = GradientBoostingRegressor()
    gbr.fit(X_train, y_train)
    pred = gbr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=195)

# %%
regressors = {
    
    'Gradient Boost Regressor' : GradientBoostingRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results

# %%
# Cross-validation of the model

# %%
gbr = GradientBoostingRegressor()
gbr.fit(X_train,y_train)
y_pred = gbr.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred

# %%
for j in range(4,10):
    isscore = cross_val_score(gbr,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')

# %%
lsscore_selected = cross_val_score(gbr,x,y,cv=9).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)

# %%
# KNeighbors Regressor
# Finding Best Random State

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    pred = knn.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=137)

# %%
regressors = {
    
    'KNN Regressor': KNeighborsRegressor()
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results

# %%
# Cross-validation of the model

# %%
knn = KNeighborsRegressor()
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(knn,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')

# %%
lsscore_selected = cross_val_score(knn,x,y,cv=9).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)

# %%
# XGBRegressor
# Finding Best Random State

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    xgb = XGBRegressor()
    xgb.fit(X_train, y_train)
    pred = xgb.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=79)

# %%
regressors = {
    
    'XG Boost Regressor' : XGBRegressor()
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results

# %%
# Cross-validation of the model

# %%
xgb = XGBRegressor()
xgb.fit(X_train,y_train)

y_pred = xgb.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(xgb,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')

# %%
lsscore_selected = cross_val_score(xgb,x,y,cv=9).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)

# %%
# Ridge

# %%
from sklearn.linear_model import Ridge

# %%
# Finding Best Random State

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    R = Ridge()
    R.fit(X_train, y_train)
    pred = R.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=67)

# %%
regressors = {
    
    'Ridge' : Ridge()
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]

# %%
results

# %%
# Cross Validation of Model

# %%
R=Ridge()
R.fit(X_train,y_train)

y_pred = R.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(xgb,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')

# %%
lsscore_selected = cross_val_score(xgb,x,y,cv=9).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)

# %%
# Selecting The Best Model
# Based on comparing Accuracy Score results with Cross Validation results, it is determined RandomForest Regressor is the best model. It has least difference between accuracy score and cross validation.
# Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=875)

# %%
rf = RandomForestRegressor()

# %%
parameters = {'criterion':['mse','mae'],
             'max_features':['auto','sqrt','log2'],
             'min_samples_split':[2,4,6,8,10],
             'min_samples_leaf':[1,3,4,5,6,7],
             'max_depth':[5,10,15],
             }

# %%
grd = GridSearchCV(rf,param_grid=parameters)

# %%
rf = RandomForestRegressor(min_samples_split=2, min_samples_leaf=1,n_estimators=500,max_features='auto')
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print(r2_score(y_test,y_pred))

# %%
# Plot Actual VS Predicted Rainfall

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=y_pred)
plt.plot(y_test,y_test)
plt.xlabel('Actual Rainfall')
plt.ylabel('Predicted Rainfall')
plt.show()

# %%
# Model Save

# %%
import pickle
pickle.dump(rf, open('Rainfall_Prediction','wb'))

# %%
# Predicting the rainfall

# %%
Prediction_accuracy = pd.DataFrame({'Predictions': rf.predict(x), 'Actual Values': y})
Prediction_accuracy.head(30)
