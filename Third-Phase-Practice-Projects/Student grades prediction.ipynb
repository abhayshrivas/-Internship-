# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv'
data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv')
data.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
print(data.shape)
# Out:
# (571, 43)

# %%
data.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
data['CGPA'] = data['CGPA'].fillna(data['CGPA'].mode()[0])

# %%
data.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
data.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
data['PH-121'] = data['PH-121'].fillna(data['PH-121'].mode()[0])

# %%
data['HS-101'] = data['HS-101'].fillna(data['HS-101'].mode()[0])

# %%
data.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
data = [1, 2, 3, 4, 5]
plt.plot(data)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(5, 43))
fig.set_facecolor('red')

plotnumber=1
data = [1, 2, 3, 4, 5]
for column in data:
    print(column)

if len(data) <= column:
    print("Error: column index out of range")
else:
    sns.distplot(data[column])

plt.figure(figsize=(5, 43))

plotnumber = 1
data = [1, 2, 3, 4, 5]

for column in data:
    if plotnumber <= 4:
        ax = plt.subplot(2, 4, plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber += 1

plt.tight_layout()
# Out:
# 1
# 2
# 3
# 4
# 5
# Error: column index out of range

# %%
url = 'https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv'
data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv')

y = data['CGPA']
x = data.drop(columns=['CGPA'])

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
x
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-306 CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419  \
# ...

# %%
print(data.columns)
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

url = 'https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv'
data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv')

columns = ['CGPA', 'PH-121', 'HS-101']
x = data[columns]

for column in columns:
    x[column] = pd.to_numeric(x[column], errors='coerce')
    
fig = plt.figure(figsize=(20,10))
plotnumber = 1

for column in columns:
    if plotnumber <= 4:
        ax = plt.subplot(2, 2, plotnumber)
        sns.distplot(x[column].dropna())
        plt.xlabel(column, fontsize=20)
        plt.ylabel('CGPA')
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-1.2094798 ,         nan,         nan],
#        [-1.52721731,         nan,         nan],
#        [ 1.05339192,         nan,         nan],
#        ...,
#        [ 0.83081437,         nan,         nan],
#        [-1.22883437,         nan,         nan],
#        [-1.9385019 ,         nan,         nan]])

# %%
help(LinearRegression)
# Out:
# Help on class LinearRegression in module sklearn.linear_model._base:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, normalize='deprecated', copy_X=True, n_jobs=None, positive=False)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  normalize : bool, default=False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state = 568 )
y_train.head()
# Out:
# 237    2.206
# 515    2.776
# 441    2.891
# 185    3.585
# 559    3.226
# Name: CGPA, dtype: float64

# %%
import numpy as np

# create sample data with NaN and inf values
a = np.array([1, 2, np.nan, np.inf, -np.inf])

# replace NaN and inf values with 0
a[np.isnan(a)] = 0
a[np.isinf(a)] = 0

# check if any values are too large for dtype('float64')
if np.any(np.abs(a) > np.finfo(np.float64).max):
    # scale the data using min-max scaling
    a_scaled = (a - np.min(a)) / (np.max(a) - np.min(a))
else:
    a_scaled = a

# %%
import numpy as np

# create an array with some values
a = np.array([1, 2, 3, np.inf, 4, 5])

# check if any values are infinite
np.isinf(a.astype(np.float64))
# Out:
# array([False, False, False,  True, False, False])

# %%
x
# Out:
#       CGPA  PH-121  HS-101
# 0    2.205     NaN     NaN
# 1    2.008     NaN     NaN
# 2    3.608     NaN     NaN
# 3    1.906     NaN     NaN
# 4    3.448     NaN     NaN
# ..     ...     ...     ...
# 566  3.798     NaN     NaN
# 567  3.772     NaN     NaN
# 568  3.470     NaN     NaN
# 569  2.193     NaN     NaN
# 570  1.753     NaN     NaN
#
# [571 rows x 3 columns]

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
print(data.isna().sum())
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
x
# Out:
#       CGPA  PH-121  HS-101
# 0    2.205     NaN     NaN
# 1    2.008     NaN     NaN
# 2    3.608     NaN     NaN
# 3    1.906     NaN     NaN
# 4    3.448     NaN     NaN
# ..     ...     ...     ...
# 566  3.798     NaN     NaN
# 567  3.772     NaN     NaN
# 568  3.470     NaN     NaN
# 569  2.193     NaN     NaN
# 570  1.753     NaN     NaN
#
# [571 rows x 3 columns]

# %%
data['AverageGrade'] = data.iloc[:, 2:].mean(axis=1)

# %%
print(data[['CGPA', 'AverageGrade']].head(10))
# Out:
#     CGPA  AverageGrade
# 0  2.205         2.205
# 1  2.008         2.008
# 2  3.608         3.608
# 3  1.906         1.906
# 4  3.448         3.448
# 5  3.026         3.026
# 6  2.957         2.957
# 7  3.043         3.043
# 8  3.358         3.358
# 9  3.247         3.247
